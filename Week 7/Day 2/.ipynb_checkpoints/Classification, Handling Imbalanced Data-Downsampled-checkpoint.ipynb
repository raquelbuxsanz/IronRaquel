# %% [markdown]
# ## Classification, Handling Imbalanced Data

# %% [markdown]
# **1. Import the required libraries and modules that you would need.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
pd.set_option('display.max_rows', 200)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **2. Read that data into Python and call the dataframe churnData.**

# %%
churnData = pd.read_csv('DATA_Customer-Churn.csv')
churnData.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract  MonthlyCharges TotalCharges Churn
# 0              No  Month-to-month           29.85        29.85    No
# 1              No        One year           56.95       1889.5    No
# 2              No  Month-to-month           53.85       108.15   Yes
# 3              No        One year           42.30      1840.75    No
# 4              No  Month-to-month           70.70       151.65   Yes

# %% [markdown]
# **3. Check the datatypes of all the columns in the data. You would see that the column TotalCharges is object type. Convert this column into numeric type using pd.to_numeric function.**

# %%
churnData['TotalCharges'].dtypes
# Out:
# dtype('O')

# %%
churnData["TotalCharges"] = pd.to_numeric(churnData["TotalCharges"], errors= 'coerce')

# %%
churnData['TotalCharges'].dtypes
# Out:
# dtype('float64')

# %%
churnData
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract  MonthlyCharges  TotalCharges Churn
# 0                 No  Month-to-month           29.85         29.85    No
# 1                 No        One year           56.95       1889.50    No
# 2                 No  Month-to-month           53.85        108.15   Yes
# 3                 No        One year           42.30       1840.75    No
# 4                 No  Month-to-month           70.70        151.65   Yes
# ...              ...             ...             ...           ...   ...
# 7038             Yes        One year           84.80       1990.50    No
# 7039             Yes        One year          103.20       7362.90    No
# 7040              No  Month-to-month           29.60        346.45    No
# 7041              No  Month-to-month           74.40        306.60   Yes
# 7042             Yes        Two year          105.65       6844.50    No
#
# [7043 rows x 16 columns]

# %% [markdown]
# **4. Check for null values in the dataframe. Replace the null values.**

# %%
mean = np.mean(churnData['TotalCharges'])
churnData['TotalCharges'] = churnData['TotalCharges'].fillna(mean)

# %%
churnData.isnull().values.any()
# Out:
# False

# %%
category_no = churnData[churnData['Churn'] == 'No']
category_yes = churnData[churnData['Churn'] == 'Yes']

# %%
print(category_no.shape)
print(category_yes.shape)
# Out:
# (5174, 16)
# (1869, 16)

# %%
category_no_down = category_no.sample(len(category_yes))
print(category_no_down.shape)
print(category_yes.shape)
# Out:
# (1869, 16)
# (1869, 16)

# %%
new_data_down= pd.concat([category_no_down, category_yes], axis=0)
new_data_down
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3456  Female              0      No         No      67          Yes
# 6937  Female              0      No         No      28           No
# 6683    Male              0      No         No      43           No
# 230     Male              0      No         No      54          Yes
# 1922    Male              0     Yes        Yes      25          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7021    Male              0      No         No      12          Yes
# 7026  Female              0      No         No       9          Yes
# 7032    Male              1      No         No       1          Yes
# 7034  Female              0      No         No      67          Yes
# 7041    Male              1     Yes         No       4          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 3456            Yes           No              Yes         Yes         Yes
# 6937             No           No              Yes         Yes          No
# 6683             No           No              Yes         Yes          No
# 230             Yes          Yes               No         Yes         Yes
# 1922             No           No               No          No         Yes
# ...             ...          ...              ...         ...         ...
# 7021             No           No               No         Yes         Yes
# 7026             No           No               No          No          No
# 7032             No           No               No          No          No
# 7034            Yes          Yes              Yes          No         Yes
# 7041             No           No               No          No          No
#
#      StreamingMovies        Contract  MonthlyCharges  TotalCharges Churn
# 3456             Yes        Two year           85.25       5714.20    No
# 6937              No  Month-to-month           35.75        961.40    No
# 6683             Yes        One year           44.15       1931.30    No
# 230              Yes        Two year          108.00       5760.65    No
# 1922              No  Month-to-month           60.35       1404.65    No
# ...              ...             ...             ...           ...   ...
# 7021              No        One year           59.80        727.80   Yes
# 7026              No  Month-to-month           44.20        403.35   Yes
# 7032              No  Month-to-month           75.75         75.75   Yes
# 7034              No  Month-to-month          102.95       6886.25   Yes
# 7041              No  Month-to-month           74.40        306.60   Yes
#
# [3738 rows x 16 columns]

# %%
#shuffling the data
new_data_down = new_data_down.sample(frac=1)
new_data_down['Churn'].value_counts()
# Out:
# Yes    1869
# No     1869
# Name: Churn, dtype: int64

# %% [markdown]
# **5. Use the following features: tenure, SeniorCitizen, MonthlyCharges and TotalCharges:**

# %% [markdown]
# *Split the data into a training set and a test set.*

# %%
X = new_data_down[['tenure','SeniorCitizen', 'MonthlyCharges', 'TotalCharges']]
y = new_data_down['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# *Scale the features either by using normalizer or a standard scaler.*

# %%
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.10577313, -0.48795004,  0.89820403,  0.38214597],
#        [-0.93593192, -0.48795004, -0.98270739, -0.82974845],
#        [-1.10260473, -0.48795004,  0.06997662, -0.89999523],
#        ...,
#        [-0.85259552, -0.48795004, -1.6995765 , -0.85487589],
#        [ 0.60579155, -0.48795004, -0.62601281,  0.07823238],
#        [-0.89426372, -0.48795004,  0.91386379, -0.66834594]])

# %% [markdown]
# *Fit a logistic Regression model on the training data*

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix


log_model = LogisticRegression() 

log_model.fit(X_train_scaled, y_train)

y_pred_train_log = log_model.predict(X_train_scaled)
y_pred_test_log = log_model.predict(X_test_scaled)

performance_log = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_log),
                                         precision_score(y_train, y_pred_train_log, pos_label='Yes'),
                                         recall_score(y_train, y_pred_train_log, pos_label='Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_log),
                                        precision_score(y_test, y_pred_test_log, pos_label='Yes'),
                                        recall_score(y_test, y_pred_test_log, pos_label='Yes')]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train,y_pred_train_log))
plot_confusion_matrix(log_model,X_train_scaled,y_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test, y_pred_test_log))
plot_confusion_matrix(log_model,X_test_scaled,y_test, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.727090  0.716578
# 1    Precision  0.722222  0.718346
# 2       Recall  0.733871  0.729659
# Confusion matrix for the train set
# [[1082  420]
#  [ 396 1092]]
# Confusion matrix for the test set
# [[258 109]
#  [103 278]]

# %% [markdown]
# *Fit a Knn Classifier model on the training data*

# %%
neigh = KNeighborsClassifier(n_neighbors=3)

neigh.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_train_knn = neigh.predict(X_train_scaled)
y_pred_test_knn  = neigh.predict(X_test_scaled)

# %%
performance_knn = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_knn),
                                         precision_score(y_train, y_pred_train_knn, pos_label='Yes'),
                                         recall_score(y_train, y_pred_train_knn, pos_label='Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_knn),
                                        precision_score(y_test, y_pred_test_knn, pos_label='Yes'),
                                        recall_score(y_test, y_pred_test_knn, pos_label='Yes')]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train,y_pred_train_knn))
plot_confusion_matrix(log_model,X_train,y_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test, y_pred_test_knn))
plot_confusion_matrix(log_model,X_test,y_test, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.727090  0.716578
# 1    Precision  0.722222  0.718346
# 2       Recall  0.733871  0.729659
# Confusion matrix for the train set
# [[1237  265]
#  [ 225 1263]]
# Confusion matrix for the test set
# [[253 114]
#  [126 255]]

# %%
performance_knn
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.836120  0.679144
# 1    Precision  0.826571  0.691057
# 2       Recall  0.848790  0.669291

# %%
full = pd.DataFrame()

models = {'k': [] }

for k in range(2,21):

    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(X_train_scaled, y_train)

    models["k"] = [k, neigh]

    y_pred_train_knn = neigh.predict(X_train_scaled)
    y_pred_test_knn  = neigh.predict(X_test_scaled)

    performance_knn = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_knn),
                                         precision_score(y_train, y_pred_train_knn, pos_label='Yes'),
                                         recall_score(y_train, y_pred_train_knn, pos_label='Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_knn),
                                        precision_score(y_test, y_pred_test_knn, pos_label='Yes'),
                                        recall_score(y_test, y_pred_test_knn, pos_label='Yes')]})
    
    temp = pd.DataFrame({'k': [k]*3, 'Error_metric': performance_knn['Error_metric'], 
                         'Train': performance_knn['Train'], 'Test': performance_knn['Test']})
    full = pd.concat([full,temp], axis=0)

full
# Out:
#     k Error_metric     Train      Test
# 0   2     Accuracy  0.837458  0.631016
# 1   2    Precision  0.997024  0.705882
# 2   2       Recall  0.675403  0.472441
# 0   3     Accuracy  0.836120  0.679144
# 1   3    Precision  0.826571  0.691057
# 2   3       Recall  0.848790  0.669291
# 0   4     Accuracy  0.804682  0.680481
# 1   4    Precision  0.866883  0.735099
# 2   4       Recall  0.717742  0.582677
# 0   5     Accuracy  0.805686  0.679144
# 1   5    Precision  0.798159  0.682171
# 2   5       Recall  0.815860  0.692913
# 0   6     Accuracy  0.781940  0.691176
# 1   6    Precision  0.828616  0.728659
# 2   6       Recall  0.708333  0.627297
# 0   7     Accuracy  0.782609  0.685829
# 1   7    Precision  0.774215  0.690104
# 2   7       Recall  0.795027  0.695538
# 0   8     Accuracy  0.775920  0.687166
# 1   8    Precision  0.802963  0.714286
# 2   8       Recall  0.728495  0.643045
# 0   9     Accuracy  0.774582  0.689840
# 1   9    Precision  0.764974  0.694517
# 2   9       Recall  0.789651  0.698163
# 0  10     Accuracy  0.771572  0.701872
# 1  10    Precision  0.783251  0.719444
# 2  10       Recall  0.747984  0.679790
# 0  11     Accuracy  0.764883  0.696524
# 1  11    Precision  0.750159  0.694444
# 2  11       Recall  0.790995  0.721785
# 0  12     Accuracy  0.764883  0.689840
# 1  12    Precision  0.770876  0.705234
# 2  12       Recall  0.750672  0.671916
# 0  13     Accuracy  0.764548  0.695187
# 1  13    Precision  0.745922  0.692695
# 2  13       Recall  0.799059  0.721785
# 0  14     Accuracy  0.757191  0.693850
# 1  14    Precision  0.760246  0.704301
# 2  14       Recall  0.747984  0.687664
# 0  15     Accuracy  0.756856  0.685829
# 1  15    Precision  0.739158  0.682500
# 2  15       Recall  0.790323  0.716535
# 0  16     Accuracy  0.756187  0.693850
# 1  16    Precision  0.755900  0.704301
# 2  16       Recall  0.753360  0.687664
# 0  17     Accuracy  0.758194  0.693850
# 1  17    Precision  0.738318  0.690000
# 2  17       Recall  0.796371  0.724409
# 0  18     Accuracy  0.755184  0.697861
# 1  18    Precision  0.750663  0.703412
# 2  18       Recall  0.760753  0.703412
# 0  19     Accuracy  0.755853  0.695187
# 1  19    Precision  0.737767  0.689826
# 2  19       Recall  0.790323  0.729659
# 0  20     Accuracy  0.752508  0.689840
# 1  20    Precision  0.748011  0.694517
# 2  20       Recall  0.758065  0.698163

# %%
models
# Out:
# {'k': [20, KNeighborsClassifier(n_neighbors=20)]}

# %%
full[full['Error_metric'] == 'Accuracy']
# Out:
#     k Error_metric     Train      Test
# 0   2     Accuracy  0.837458  0.631016
# 0   3     Accuracy  0.836120  0.679144
# 0   4     Accuracy  0.804682  0.680481
# 0   5     Accuracy  0.805686  0.679144
# 0   6     Accuracy  0.781940  0.691176
# 0   7     Accuracy  0.782609  0.685829
# 0   8     Accuracy  0.775920  0.687166
# 0   9     Accuracy  0.774582  0.689840
# 0  10     Accuracy  0.771572  0.701872
# 0  11     Accuracy  0.764883  0.696524
# 0  12     Accuracy  0.764883  0.689840
# 0  13     Accuracy  0.764548  0.695187
# 0  14     Accuracy  0.757191  0.693850
# 0  15     Accuracy  0.756856  0.685829
# 0  16     Accuracy  0.756187  0.693850
# 0  17     Accuracy  0.758194  0.693850
# 0  18     Accuracy  0.755184  0.697861
# 0  19     Accuracy  0.755853  0.695187
# 0  20     Accuracy  0.752508  0.689840

# %%
full2 = full.melt(id_vars=['k','Error_metric'])
full2
# Out:
#       k Error_metric variable     value
# 0     2     Accuracy    Train  0.837458
# 1     2    Precision    Train  0.997024
# 2     2       Recall    Train  0.675403
# 3     3     Accuracy    Train  0.836120
# 4     3    Precision    Train  0.826571
# 5     3       Recall    Train  0.848790
# 6     4     Accuracy    Train  0.804682
# 7     4    Precision    Train  0.866883
# 8     4       Recall    Train  0.717742
# 9     5     Accuracy    Train  0.805686
# 10    5    Precision    Train  0.798159
# 11    5       Recall    Train  0.815860
# 12    6     Accuracy    Train  0.781940
# 13    6    Precision    Train  0.828616
# 14    6       Recall    Train  0.708333
# 15    7     Accuracy    Train  0.782609
# 16    7    Precision    Train  0.774215
# 17    7       Recall    Train  0.795027
# 18    8     Accuracy    Train  0.775920
# 19    8    Precision    Train  0.802963
# 20    8       Recall    Train  0.728495
# 21    9     Accuracy    Train  0.774582
# 22    9    Precision    Train  0.764974
# 23    9       Recall    Train  0.789651
# 24   10     Accuracy    Train  0.771572
# 25   10    Precision    Train  0.783251
# 26   10       Recall    Train  0.747984
# 27   11     Accuracy    Train  0.764883
# 28   11    Precision    Train  0.750159
# 29   11       Recall    Train  0.790995
# 30   12     Accuracy    Train  0.764883
# 31   12    Precision    Train  0.770876
# 32   12       Recall    Train  0.750672
# 33   13     Accuracy    Train  0.764548
# 34   13    Precision    Train  0.745922
# 35   13       Recall    Train  0.799059
# 36   14     Accuracy    Train  0.757191
# 37   14    Precision    Train  0.760246
# 38   14       Recall    Train  0.747984
# 39   15     Accuracy    Train  0.756856
# 40   15    Precision    Train  0.739158
# 41   15       Recall    Train  0.790323
# 42   16     Accuracy    Train  0.756187
# 43   16    Precision    Train  0.755900
# 44   16       Recall    Train  0.753360
# 45   17     Accuracy    Train  0.758194
# 46   17    Precision    Train  0.738318
# 47   17       Recall    Train  0.796371
# 48   18     Accuracy    Train  0.755184
# 49   18    Precision    Train  0.750663
# 50   18       Recall    Train  0.760753
# 51   19     Accuracy    Train  0.755853
# 52   19    Precision    Train  0.737767
# 53   19       Recall    Train  0.790323
# 54   20     Accuracy    Train  0.752508
# 55   20    Precision    Train  0.748011
# 56   20       Recall    Train  0.758065
# 57    2     Accuracy     Test  0.631016
# 58    2    Precision     Test  0.705882
# 59    2       Recall     Test  0.472441
# 60    3     Accuracy     Test  0.679144
# 61    3    Precision     Test  0.691057
# 62    3       Recall     Test  0.669291
# 63    4     Accuracy     Test  0.680481
# 64    4    Precision     Test  0.735099
# 65    4       Recall     Test  0.582677
# 66    5     Accuracy     Test  0.679144
# 67    5    Precision     Test  0.682171
# 68    5       Recall     Test  0.692913
# 69    6     Accuracy     Test  0.691176
# 70    6    Precision     Test  0.728659
# 71    6       Recall     Test  0.627297
# 72    7     Accuracy     Test  0.685829
# 73    7    Precision     Test  0.690104
# 74    7       Recall     Test  0.695538
# 75    8     Accuracy     Test  0.687166
# 76    8    Precision     Test  0.714286
# 77    8       Recall     Test  0.643045
# 78    9     Accuracy     Test  0.689840
# 79    9    Precision     Test  0.694517
# 80    9       Recall     Test  0.698163
# 81   10     Accuracy     Test  0.701872
# 82   10    Precision     Test  0.719444
# 83   10       Recall     Test  0.679790
# 84   11     Accuracy     Test  0.696524
# 85   11    Precision     Test  0.694444
# 86   11       Recall     Test  0.721785
# 87   12     Accuracy     Test  0.689840
# 88   12    Precision     Test  0.705234
# 89   12       Recall     Test  0.671916
# 90   13     Accuracy     Test  0.695187
# 91   13    Precision     Test  0.692695
# 92   13       Recall     Test  0.721785
# 93   14     Accuracy     Test  0.693850
# 94   14    Precision     Test  0.704301
# 95   14       Recall     Test  0.687664
# 96   15     Accuracy     Test  0.685829
# 97   15    Precision     Test  0.682500
# 98   15       Recall     Test  0.716535
# 99   16     Accuracy     Test  0.693850
# 100  16    Precision     Test  0.704301
# 101  16       Recall     Test  0.687664
# 102  17     Accuracy     Test  0.693850
# 103  17    Precision     Test  0.690000
# 104  17       Recall     Test  0.724409
# 105  18     Accuracy     Test  0.697861
# 106  18    Precision     Test  0.703412
# 107  18       Recall     Test  0.703412
# 108  19     Accuracy     Test  0.695187
# 109  19    Precision     Test  0.689826
# 110  19       Recall     Test  0.729659
# 111  20     Accuracy     Test  0.689840
# 112  20    Precision     Test  0.694517
# 113  20       Recall     Test  0.698163

# %%
fig, ax = plt.subplots(1,3, figsize=(20,10))

sns.lineplot(x = 'k', y = 'value', data = full2[full2['Error_metric'] == 'Accuracy'], hue = 'variable', ax = ax[0])
ax[0].set_xticks(range(2,21))
ax[0].set_title("Accuracy")
ax[0].legend(loc='lower left')

sns.lineplot(x = 'k', y = 'value', data = full2[full2['Error_metric'] == 'Recall'], hue = 'variable', ax = ax[1])
ax[1].set_xticks(range(2,21))
ax[1].set_title("Recall")
ax[1].legend(loc='lower right')

sns.lineplot(x = 'k', y = 'value', data = full2[full2['Error_metric'] == 'Precision'], hue = 'variable', ax = ax[2])
ax[2].set_xticks(range(2,21))
ax[2].set_title("Precision")
ax[2].legend(loc='lower right')

# %% [markdown]
# ## Fit a Decision Tree Classifier on the training data.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix



# Bear in mind that sklearn uses a different function for decission trees used for 
# classification ( to predict a categorical feature ): DecisionTreeClassifier() 
dt = DecisionTreeClassifier(max_depth=3)

dt.fit(X_train, y_train)

y_pred_train_dt = dt.predict(X_train)
y_pred_test_dt = dt.predict(X_test)


performance_df = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_dt),
                                         precision_score(y_train, y_pred_train_dt, pos_label= 'Yes'),
                                         recall_score(y_train, y_pred_train_dt, pos_label= 'Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_dt),
                                        precision_score(y_test, y_pred_test_dt, pos_label= 'Yes'),
                                        recall_score(y_test, y_pred_test_dt, pos_label= 'Yes')]})


display(performance_df)

fig, ax = plt.subplots(1,2, figsize=(14,8))


#print("Confusion matrix for the train set")
#print(confusion_matrix(y_train,y_pred_train_dt).T)
plot_confusion_matrix(dt,X_train,y_train,ax=ax[0], values_format = 'd')
ax[0].title.set_text("Train Set")

#print("Confusion matrix for the test set")

#print(confusion_matrix(y_test,y_pred_test_dt).T)
plot_confusion_matrix(dt,X_test,y_test,ax=ax[1],values_format = 'd')
ax[1].title.set_text("Test Set")
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.730769  0.683155
# 1    Precision  0.692829  0.658590
# 2       Recall  0.824597  0.784777

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (34,20))

plot_tree(dt,filled = True, rounded=True,feature_names=X.columns)
plt.show()

# %% [markdown]
# ## Apply K-fold Cross Validation on your models before and check the model score.

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2990, 4)
# (748, 4)

# %%
scores=cross_val_score(dt, X_train, y_train, cv=10)
scores
# Out:
# array([0.71571906, 0.72240803, 0.73244147, 0.70234114, 0.69230769,
#        0.7458194 , 0.72240803, 0.73578595, 0.7090301 , 0.74916388])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.72 accuracy with a standard deviation of 0.02

# %%
model1 = DecisionTreeClassifier()

model2 = LogisticRegression()

model3 = KNeighborsClassifier()


model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, X_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.6795986622073579, 'Linear Regression': 0.7264214046822742, 'KNN': 0.7023411371237458}

# %% [markdown]
# ## Check for Imbalance

# %% [markdown]
# *When there is an imbalance in the data, the training model will spend most of its time on negative examples and not learn enough from positive ones. For exaple, the cases of fraud are always going to be way less than the cases of no fraud.*
#
# **The methods to check imbalanced data are:**
# + **Downsampling:** *means training on a disproportionately low subset of the majority class examples.*
# + **Upsampling:** *means adding an example weight to the downsampled class equal to the factor by which you downsampled.*
# + **Upsampling SMOTE**
# + **Downsampling Tomeklinks**

# %% [markdown]
# *First, check if our data is imbalanced*

# %%
churnData['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
5174/len(churnData['Churn'])
# Out:
# 0.7346301292063041

# %% [markdown]
# *Downsampling*

# %%
category_no = churnData[churnData['Churn'] == 'No']
category_yes = churnData[churnData['Churn'] == 'Yes']

# %%
print(category_no.shape)
print(category_yes.shape)
# Out:
# (5174, 16)
# (1869, 16)

# %%
category_no_down = category_no.sample(len(category_yes))
print(category_no_down.shape)
print(category_yes.shape)
# Out:
# (1869, 16)
# (1869, 16)

# %%
new_data_down= pd.concat([category_no_down, category_yes], axis=0)
new_data_down
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5379  Female              0     Yes         No      56          Yes
# 6774  Female              0      No         No       1          Yes
# 4467  Female              0     Yes         No      48          Yes
# 5669    Male              1     Yes         No      43          Yes
# 6576  Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7021    Male              0      No         No      12          Yes
# 7026  Female              0      No         No       9          Yes
# 7032    Male              1      No         No       1          Yes
# 7034  Female              0      No         No      67          Yes
# 7041    Male              1     Yes         No       4          Yes
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 5379                  Yes                   No                   No
# 6774  No internet service  No internet service  No internet service
# 4467                   No                   No                  Yes
# 5669                   No                  Yes                  Yes
# 6576  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7021                   No                   No                   No
# 7026                   No                   No                   No
# 7032                   No                   No                   No
# 7034                  Yes                  Yes                  Yes
# 7041                   No                   No                   No
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 5379                   No                  Yes                  Yes
# 6774  No internet service  No internet service  No internet service
# 4467                  Yes                   No                  Yes
# 5669                   No                  Yes                  Yes
# 6576  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7021                  Yes                  Yes                   No
# 7026                   No                   No                   No
# 7032                   No                   No                   No
# 7034                   No                  Yes                   No
# 7041                   No                   No                   No
#
#             Contract  MonthlyCharges  TotalCharges Churn
# 5379        One year           98.00       5270.60    No
# 6774  Month-to-month           19.65         19.65    No
# 4467        One year           69.55       3435.60    No
# 5669        One year          100.55       4304.00    No
# 6576  Month-to-month           20.30         41.20    No
# ...              ...             ...           ...   ...
# 7021        One year           59.80        727.80   Yes
# 7026  Month-to-month           44.20        403.35   Yes
# 7032  Month-to-month           75.75         75.75   Yes
# 7034  Month-to-month          102.95       6886.25   Yes
# 7041  Month-to-month           74.40        306.60   Yes
#
# [3738 rows x 16 columns]

# %%
#shuffling the data
new_data_down = new_data_down.sample(frac=1)
new_data_down['Churn'].value_counts()
# Out:
# Yes    1869
# No     1869
# Name: Churn, dtype: int64

# %% [markdown]
# *Upsampling*

# %%
category_yes_up = category_yes.sample(len(category_no), replace=True) 
print(category_yes_up.shape)
# Out:
# (5174, 16)

# %%
category_no.shape
# Out:
# (5174, 16)

# %%
new_data_up= pd.concat([category_no, category_yes_up], axis=0)
new_data_up
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 4548  Female              0      No         No      22          Yes
# 945   Female              0      No         No       3          Yes
# 4908  Female              1      No         No      28          Yes
# 6434    Male              0      No         No       1          Yes
# 995   Female              0      No         No      35          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 3               Yes           No              Yes         Yes          No
# 6                No          Yes               No          No         Yes
# 7               Yes           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 4548             No          Yes               No          No          No
# 945              No           No               No          No          No
# 4908             No          Yes              Yes          No         Yes
# 6434             No           No              Yes          No          No
# 995              No          Yes               No         Yes          No
#
#      StreamingMovies        Contract  MonthlyCharges  TotalCharges Churn
# 0                 No  Month-to-month           29.85         29.85    No
# 1                 No        One year           56.95       1889.50    No
# 3                 No        One year           42.30       1840.75    No
# 6                 No  Month-to-month           89.10       1949.40    No
# 7                 No  Month-to-month           29.75        301.90    No
# ...              ...             ...             ...           ...   ...
# 4548             Yes  Month-to-month           84.30       1855.65   Yes
# 945               No  Month-to-month           74.40        215.80   Yes
# 4908             Yes  Month-to-month          106.15       3152.50   Yes
# 6434              No  Month-to-month           50.50         50.50   Yes
# 995               No  Month-to-month           85.30       2917.50   Yes
#
# [10348 rows x 16 columns]

# %%
new_data_up['Churn'].value_counts()
# Out:
# No     5174
# Yes    5174
# Name: Churn, dtype: int64

# %% [markdown]
# ##  Fit a Random forest Classifier on the data and compare the accuracy.

# %%
from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(random_state=0, max_features='sqrt', 
                             min_samples_leaf=1, min_samples_split=2, n_estimators=100)
cross_val_scores = cross_val_score(clf, X_train, y_train, cv=10)
print(np.mean(cross_val_scores))
# Out:
# 0.7153846153846153
