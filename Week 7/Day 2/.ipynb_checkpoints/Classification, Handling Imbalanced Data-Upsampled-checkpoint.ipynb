# %% [markdown]
# ## Classification, Handling Imbalanced Data

# %% [markdown]
# **1. Import the required libraries and modules that you would need.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
pd.set_option('display.max_rows', 200)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **2. Read that data into Python and call the dataframe churnData.**

# %%
churnData = pd.read_csv('DATA_Customer-Churn.csv')
churnData.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract  MonthlyCharges TotalCharges Churn
# 0              No  Month-to-month           29.85        29.85    No
# 1              No        One year           56.95       1889.5    No
# 2              No  Month-to-month           53.85       108.15   Yes
# 3              No        One year           42.30      1840.75    No
# 4              No  Month-to-month           70.70       151.65   Yes

# %% [markdown]
# **3. Check the datatypes of all the columns in the data. You would see that the column TotalCharges is object type. Convert this column into numeric type using pd.to_numeric function.**

# %%
churnData['TotalCharges'].dtypes
# Out:
# dtype('O')

# %%
churnData["TotalCharges"] = pd.to_numeric(churnData["TotalCharges"], errors= 'coerce')

# %%
churnData['TotalCharges'].dtypes
# Out:
# dtype('float64')

# %%
churnData
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract  MonthlyCharges  TotalCharges Churn
# 0                 No  Month-to-month           29.85         29.85    No
# 1                 No        One year           56.95       1889.50    No
# 2                 No  Month-to-month           53.85        108.15   Yes
# 3                 No        One year           42.30       1840.75    No
# 4                 No  Month-to-month           70.70        151.65   Yes
# ...              ...             ...             ...           ...   ...
# 7038             Yes        One year           84.80       1990.50    No
# 7039             Yes        One year          103.20       7362.90    No
# 7040              No  Month-to-month           29.60        346.45    No
# 7041              No  Month-to-month           74.40        306.60   Yes
# 7042             Yes        Two year          105.65       6844.50    No
#
# [7043 rows x 16 columns]

# %% [markdown]
# **4. Check for null values in the dataframe. Replace the null values.**

# %%
mean = np.mean(churnData['TotalCharges'])
churnData['TotalCharges'] = churnData['TotalCharges'].fillna(mean)

# %%
churnData.isnull().values.any()
# Out:
# False

# %%
category_no = churnData[churnData['Churn'] == 'No']
category_yes = churnData[churnData['Churn'] == 'Yes']

# %%
category_yes_up = category_yes.sample(len(category_no), replace=True) 
print(category_yes_up.shape)
# Out:
# (5174, 16)

# %%
category_no.shape
# Out:
# (5174, 16)

# %%
new_data_up= pd.concat([category_no, category_yes_up], axis=0)
new_data_up
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 4610    Male              0     Yes         No      72          Yes
# 1990  Female              1      No         No      16          Yes
# 2756  Female              0      No         No       1          Yes
# 4673  Female              1      No         No      25          Yes
# 1985  Female              0     Yes        Yes      12           No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                      No                  Yes                   No
# 1                     Yes                   No                  Yes
# 3                     Yes                   No                  Yes
# 6                      No                  Yes                   No
# 7                     Yes                   No                   No
# ...                   ...                  ...                  ...
# 4610                  Yes                  Yes                  Yes
# 1990                   No                   No                   No
# 2756  No internet service  No internet service  No internet service
# 4673                  Yes                  Yes                   No
# 1985                   No                  Yes                   No
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 0                      No                   No                   No
# 1                      No                   No                   No
# 3                     Yes                   No                   No
# 6                      No                  Yes                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 4610                  Yes                  Yes                  Yes
# 1990                   No                  Yes                   No
# 2756  No internet service  No internet service  No internet service
# 4673                   No                  Yes                  Yes
# 1985                   No                   No                   No
#
#             Contract  MonthlyCharges  TotalCharges Churn
# 0     Month-to-month           29.85         29.85    No
# 1           One year           56.95       1889.50    No
# 3           One year           42.30       1840.75    No
# 6     Month-to-month           89.10       1949.40    No
# 7     Month-to-month           29.75        301.90    No
# ...              ...             ...           ...   ...
# 4610        One year          117.80       8684.80   Yes
# 1990  Month-to-month           84.75       1350.15   Yes
# 2756  Month-to-month           20.95         20.95   Yes
# 4673  Month-to-month          102.80       2660.20   Yes
# 1985  Month-to-month           29.20        309.10   Yes
#
# [10348 rows x 16 columns]

# %%
new_data_up['Churn'].value_counts()
# Out:
# No     5174
# Yes    5174
# Name: Churn, dtype: int64

# %% [markdown]
# **5. Use the following features: tenure, SeniorCitizen, MonthlyCharges and TotalCharges:**

# %% [markdown]
# *Split the data into a training set and a test set.*

# %%
X = new_data_up[['tenure','SeniorCitizen', 'MonthlyCharges', 'TotalCharges']]
y = new_data_up['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# *Scale the features either by using normalizer or a standard scaler.*

# %%
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-1.10449082, -0.48720551, -1.67698148, -0.91972763],
#        [-1.02128853, -0.48720551, -0.42953101, -0.83848769],
#        [-1.02128853, -0.48720551,  0.27237704, -0.82724969],
#        ...,
#        [ 0.26834699, -0.48720551,  1.12543857,  0.67087454],
#        [ 1.64118481, -0.48720551,  0.16292108,  1.36560817],
#        [-0.56367593, -0.48720551,  0.60769451, -0.40503182]])

# %% [markdown]
# *Fit a logistic Regression model on the training data*

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix


log_model = LogisticRegression() 

log_model.fit(X_train_scaled, y_train)

y_pred_train_log = log_model.predict(X_train_scaled)
y_pred_test_log = log_model.predict(X_test_scaled)

performance_log = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_log),
                                         precision_score(y_train, y_pred_train_log, pos_label='Yes'),
                                         recall_score(y_train, y_pred_train_log, pos_label='Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_log),
                                        precision_score(y_test, y_pred_test_log, pos_label='Yes'),
                                        recall_score(y_test, y_pred_test_log, pos_label='Yes')]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train,y_pred_train_log))
plot_confusion_matrix(log_model,X_train_scaled,y_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test, y_pred_test_log))
plot_confusion_matrix(log_model,X_test_scaled,y_test, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.732906  0.711594
# 1    Precision  0.730102  0.713858
# 2       Recall  0.740839  0.697856
# Confusion matrix for the train set
# [[2994 1136]
#  [1075 3073]]
# Confusion matrix for the test set
# [[757 287]
#  [310 716]]

# %% [markdown]
# *Fit a Knn Classifier model on the training data*

# %%
neigh = KNeighborsClassifier(n_neighbors=3)

neigh.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_train_knn = neigh.predict(X_train_scaled)
y_pred_test_knn  = neigh.predict(X_test_scaled)

# %%
performance_knn = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_knn),
                                         precision_score(y_train, y_pred_train_knn, pos_label='Yes'),
                                         recall_score(y_train, y_pred_train_knn, pos_label='Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_knn),
                                        precision_score(y_test, y_pred_test_knn, pos_label='Yes'),
                                        recall_score(y_test, y_pred_test_knn, pos_label='Yes')]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train,y_pred_train_knn))
plot_confusion_matrix(log_model,X_train,y_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test, y_pred_test_knn))
plot_confusion_matrix(log_model,X_test,y_test, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.732906  0.711594
# 1    Precision  0.730102  0.713858
# 2       Recall  0.740839  0.697856
# Confusion matrix for the train set
# [[3435  695]
#  [ 145 4003]]
# Confusion matrix for the test set
# [[771 273]
#  [123 903]]

# %%
performance_knn
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.898526  0.808696
# 1    Precision  0.852065  0.767857
# 2       Recall  0.965043  0.880117

# %%
full = pd.DataFrame()

models = {'k': [] }

for k in range(2,21):

    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(X_train_scaled, y_train)

    models["k"] = [k, neigh]

    y_pred_train_knn = neigh.predict(X_train_scaled)
    y_pred_test_knn  = neigh.predict(X_test_scaled)

    performance_knn = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_knn),
                                         precision_score(y_train, y_pred_train_knn, pos_label='Yes'),
                                         recall_score(y_train, y_pred_train_knn, pos_label='Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_knn),
                                        precision_score(y_test, y_pred_test_knn, pos_label='Yes'),
                                        recall_score(y_test, y_pred_test_knn, pos_label='Yes')]})
    
    temp = pd.DataFrame({'k': [k]*3, 'Error_metric': performance_knn['Error_metric'], 
                         'Train': performance_knn['Train'], 'Test': performance_knn['Test']})
    full = pd.concat([full,temp], axis=0)

full
# Out:
#     k Error_metric     Train      Test
# 0   2     Accuracy  0.960135  0.823188
# 1   2    Precision  0.994303  0.831992
# 2   2       Recall  0.925747  0.806043
# 0   3     Accuracy  0.898526  0.808696
# 1   3    Precision  0.852065  0.767857
# 2   3       Recall  0.965043  0.880117
# 0   4     Accuracy  0.878111  0.774879
# 1   4    Precision  0.874851  0.780561
# 2   4       Recall  0.883076  0.759259
# 0   5     Accuracy  0.845373  0.770531
# 1   5    Precision  0.801641  0.743590
# 2   5       Recall  0.918756  0.819688
# 0   6     Accuracy  0.834501  0.754589
# 1   6    Precision  0.827440  0.761089
# 2   6       Recall  0.846191  0.735867
# 0   7     Accuracy  0.821938  0.758454
# 1   7    Precision  0.786541  0.735242
# 2   7       Recall  0.884764  0.801170
# 0   8     Accuracy  0.806958  0.742995
# 1   8    Precision  0.805755  0.753074
# 2   8       Recall  0.810029  0.716374
# 0   9     Accuracy  0.803817  0.744928
# 1   9    Precision  0.775787  0.733146
# 2   9       Recall  0.855834  0.763158
# 0  10     Accuracy  0.795603  0.745894
# 1  10    Precision  0.793499  0.754582
# 2  10       Recall  0.800386  0.722222
# 0  11     Accuracy  0.795120  0.748792
# 1  11    Precision  0.771479  0.738679
# 2  11       Recall  0.839923  0.763158
# 0  12     Accuracy  0.794999  0.745894
# 1  12    Precision  0.789648  0.749501
# 2  12       Recall  0.805448  0.731969
# 0  13     Accuracy  0.788596  0.749758
# 1  13    Precision  0.767038  0.737828
# 2  13       Recall  0.830280  0.768031
# 0  14     Accuracy  0.789200  0.745411
# 1  14    Precision  0.781580  0.746785
# 2  14       Recall  0.804002  0.735867
# 0  15     Accuracy  0.787147  0.746377
# 1  15    Precision  0.762891  0.733023
# 2  15       Recall  0.834619  0.768031
# 0  16     Accuracy  0.785455  0.744444
# 1  16    Precision  0.775686  0.741967
# 2  16       Recall  0.804484  0.742690
# 0  17     Accuracy  0.784127  0.746377
# 1  17    Precision  0.762508  0.731302
# 2  17       Recall  0.826663  0.771930
# 0  18     Accuracy  0.783039  0.753140
# 1  18    Precision  0.774254  0.752204
# 2  18       Recall  0.800386  0.748538
# 0  19     Accuracy  0.779415  0.754106
# 1  19    Precision  0.758575  0.740913
# 2  19       Recall  0.821119  0.774854
# 0  20     Accuracy  0.774221  0.749275
# 1  20    Precision  0.768687  0.747801
# 2  20       Recall  0.785921  0.745614

# %%
models
# Out:
# {'k': [20, KNeighborsClassifier(n_neighbors=20)]}

# %%
full[full['Error_metric'] == 'Accuracy']
# Out:
#     k Error_metric     Train      Test
# 0   2     Accuracy  0.960135  0.823188
# 0   3     Accuracy  0.898526  0.808696
# 0   4     Accuracy  0.878111  0.774879
# 0   5     Accuracy  0.845373  0.770531
# 0   6     Accuracy  0.834501  0.754589
# 0   7     Accuracy  0.821938  0.758454
# 0   8     Accuracy  0.806958  0.742995
# 0   9     Accuracy  0.803817  0.744928
# 0  10     Accuracy  0.795603  0.745894
# 0  11     Accuracy  0.795120  0.748792
# 0  12     Accuracy  0.794999  0.745894
# 0  13     Accuracy  0.788596  0.749758
# 0  14     Accuracy  0.789200  0.745411
# 0  15     Accuracy  0.787147  0.746377
# 0  16     Accuracy  0.785455  0.744444
# 0  17     Accuracy  0.784127  0.746377
# 0  18     Accuracy  0.783039  0.753140
# 0  19     Accuracy  0.779415  0.754106
# 0  20     Accuracy  0.774221  0.749275

# %%
full2 = full.melt(id_vars=['k','Error_metric'])
full2
# Out:
#       k Error_metric variable     value
# 0     2     Accuracy    Train  0.960135
# 1     2    Precision    Train  0.994303
# 2     2       Recall    Train  0.925747
# 3     3     Accuracy    Train  0.898526
# 4     3    Precision    Train  0.852065
# 5     3       Recall    Train  0.965043
# 6     4     Accuracy    Train  0.878111
# 7     4    Precision    Train  0.874851
# 8     4       Recall    Train  0.883076
# 9     5     Accuracy    Train  0.845373
# 10    5    Precision    Train  0.801641
# 11    5       Recall    Train  0.918756
# 12    6     Accuracy    Train  0.834501
# 13    6    Precision    Train  0.827440
# 14    6       Recall    Train  0.846191
# 15    7     Accuracy    Train  0.821938
# 16    7    Precision    Train  0.786541
# 17    7       Recall    Train  0.884764
# 18    8     Accuracy    Train  0.806958
# 19    8    Precision    Train  0.805755
# 20    8       Recall    Train  0.810029
# 21    9     Accuracy    Train  0.803817
# 22    9    Precision    Train  0.775787
# 23    9       Recall    Train  0.855834
# 24   10     Accuracy    Train  0.795603
# 25   10    Precision    Train  0.793499
# 26   10       Recall    Train  0.800386
# 27   11     Accuracy    Train  0.795120
# 28   11    Precision    Train  0.771479
# 29   11       Recall    Train  0.839923
# 30   12     Accuracy    Train  0.794999
# 31   12    Precision    Train  0.789648
# 32   12       Recall    Train  0.805448
# 33   13     Accuracy    Train  0.788596
# 34   13    Precision    Train  0.767038
# 35   13       Recall    Train  0.830280
# 36   14     Accuracy    Train  0.789200
# 37   14    Precision    Train  0.781580
# 38   14       Recall    Train  0.804002
# 39   15     Accuracy    Train  0.787147
# 40   15    Precision    Train  0.762891
# 41   15       Recall    Train  0.834619
# 42   16     Accuracy    Train  0.785455
# 43   16    Precision    Train  0.775686
# 44   16       Recall    Train  0.804484
# 45   17     Accuracy    Train  0.784127
# 46   17    Precision    Train  0.762508
# 47   17       Recall    Train  0.826663
# 48   18     Accuracy    Train  0.783039
# 49   18    Precision    Train  0.774254
# 50   18       Recall    Train  0.800386
# 51   19     Accuracy    Train  0.779415
# 52   19    Precision    Train  0.758575
# 53   19       Recall    Train  0.821119
# 54   20     Accuracy    Train  0.774221
# 55   20    Precision    Train  0.768687
# 56   20       Recall    Train  0.785921
# 57    2     Accuracy     Test  0.823188
# 58    2    Precision     Test  0.831992
# 59    2       Recall     Test  0.806043
# 60    3     Accuracy     Test  0.808696
# 61    3    Precision     Test  0.767857
# 62    3       Recall     Test  0.880117
# 63    4     Accuracy     Test  0.774879
# 64    4    Precision     Test  0.780561
# 65    4       Recall     Test  0.759259
# 66    5     Accuracy     Test  0.770531
# 67    5    Precision     Test  0.743590
# 68    5       Recall     Test  0.819688
# 69    6     Accuracy     Test  0.754589
# 70    6    Precision     Test  0.761089
# 71    6       Recall     Test  0.735867
# 72    7     Accuracy     Test  0.758454
# 73    7    Precision     Test  0.735242
# 74    7       Recall     Test  0.801170
# 75    8     Accuracy     Test  0.742995
# 76    8    Precision     Test  0.753074
# 77    8       Recall     Test  0.716374
# 78    9     Accuracy     Test  0.744928
# 79    9    Precision     Test  0.733146
# 80    9       Recall     Test  0.763158
# 81   10     Accuracy     Test  0.745894
# 82   10    Precision     Test  0.754582
# 83   10       Recall     Test  0.722222
# 84   11     Accuracy     Test  0.748792
# 85   11    Precision     Test  0.738679
# 86   11       Recall     Test  0.763158
# 87   12     Accuracy     Test  0.745894
# 88   12    Precision     Test  0.749501
# 89   12       Recall     Test  0.731969
# 90   13     Accuracy     Test  0.749758
# 91   13    Precision     Test  0.737828
# 92   13       Recall     Test  0.768031
# 93   14     Accuracy     Test  0.745411
# 94   14    Precision     Test  0.746785
# 95   14       Recall     Test  0.735867
# 96   15     Accuracy     Test  0.746377
# 97   15    Precision     Test  0.733023
# 98   15       Recall     Test  0.768031
# 99   16     Accuracy     Test  0.744444
# 100  16    Precision     Test  0.741967
# 101  16       Recall     Test  0.742690
# 102  17     Accuracy     Test  0.746377
# 103  17    Precision     Test  0.731302
# 104  17       Recall     Test  0.771930
# 105  18     Accuracy     Test  0.753140
# 106  18    Precision     Test  0.752204
# 107  18       Recall     Test  0.748538
# 108  19     Accuracy     Test  0.754106
# 109  19    Precision     Test  0.740913
# 110  19       Recall     Test  0.774854
# 111  20     Accuracy     Test  0.749275
# 112  20    Precision     Test  0.747801
# 113  20       Recall     Test  0.745614

# %%
fig, ax = plt.subplots(1,3, figsize=(20,10))

sns.lineplot(x = 'k', y = 'value', data = full2[full2['Error_metric'] == 'Accuracy'], hue = 'variable', ax = ax[0])
ax[0].set_xticks(range(2,21))
ax[0].set_title("Accuracy")
ax[0].legend(loc='lower left')

sns.lineplot(x = 'k', y = 'value', data = full2[full2['Error_metric'] == 'Recall'], hue = 'variable', ax = ax[1])
ax[1].set_xticks(range(2,21))
ax[1].set_title("Recall")
ax[1].legend(loc='lower right')

sns.lineplot(x = 'k', y = 'value', data = full2[full2['Error_metric'] == 'Precision'], hue = 'variable', ax = ax[2])
ax[2].set_xticks(range(2,21))
ax[2].set_title("Precision")
ax[2].legend(loc='lower right')

# %% [markdown]
# ## Fit a Decision Tree Classifier on the training data.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix



# Bear in mind that sklearn uses a different function for decission trees used for 
# classification ( to predict a categorical feature ): DecisionTreeClassifier() 
dt = DecisionTreeClassifier(max_depth=3)

dt.fit(X_train, y_train)

y_pred_train_dt = dt.predict(X_train)
y_pred_test_dt = dt.predict(X_test)


performance_df = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_dt),
                                         precision_score(y_train, y_pred_train_dt, pos_label= 'Yes'),
                                         recall_score(y_train, y_pred_train_dt, pos_label= 'Yes')],
                               'Test': [accuracy_score(y_test, y_pred_test_dt),
                                        precision_score(y_test, y_pred_test_dt, pos_label= 'Yes'),
                                        recall_score(y_test, y_pred_test_dt, pos_label= 'Yes')]})


display(performance_df)

fig, ax = plt.subplots(1,2, figsize=(14,8))


#print("Confusion matrix for the train set")
#print(confusion_matrix(y_train,y_pred_train_dt).T)
plot_confusion_matrix(dt,X_train,y_train,ax=ax[0], values_format = 'd')
ax[0].title.set_text("Train Set")

#print("Confusion matrix for the test set")

#print(confusion_matrix(y_test,y_pred_test_dt).T)
plot_confusion_matrix(dt,X_test,y_test,ax=ax[1],values_format = 'd')
ax[1].title.set_text("Test Set")
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.733873  0.727536
# 1    Precision  0.702393  0.699138
# 2       Recall  0.813645  0.790448

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (34,20))

plot_tree(dt,filled = True, rounded=True,feature_names=X.columns)
plt.show()

# %% [markdown]
# ## Apply K-fold Cross Validation on your models before and check the model score.

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (8278, 4)
# (2070, 4)

# %%
scores=cross_val_score(dt, X_train, y_train, cv=10)
scores
# Out:
# array([0.72463768, 0.72222222, 0.73309179, 0.71859903, 0.71256039,
#        0.7294686 , 0.73550725, 0.72222222, 0.73035067, 0.74244256])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.73 accuracy with a standard deviation of 0.01

# %%
model1 = DecisionTreeClassifier()

model2 = LogisticRegression()

model3 = KNeighborsClassifier()


model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, X_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.8383666097464862, 'Linear Regression': 0.7378604579885284, 'KNN': 0.75066589313601}

# %% [markdown]
# ## Check for Imbalance

# %% [markdown]
# *When there is an imbalance in the data, the training model will spend most of its time on negative examples and not learn enough from positive ones. For exaple, the cases of fraud are always going to be way less than the cases of no fraud.*
#
# **The methods to check imbalanced data are:**
# + **Downsampling:** *means training on a disproportionately low subset of the majority class examples.*
# + **Upsampling:** *means adding an example weight to the downsampled class equal to the factor by which you downsampled.*
# + **Upsampling SMOTE**
# + **Downsampling Tomeklinks**

# %% [markdown]
# *First, check if our data is imbalanced*

# %%
churnData['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
5174/len(churnData['Churn'])
# Out:
# 0.7346301292063041

# %% [markdown]
# *Downsampling*

# %%
category_no = churnData[churnData['Churn'] == 'No']
category_yes = churnData[churnData['Churn'] == 'Yes']

# %%
print(category_no.shape)
print(category_yes.shape)
# Out:
# (5174, 16)
# (1869, 16)

# %%
category_no_down = category_no.sample(len(category_yes))
print(category_no_down.shape)
print(category_yes.shape)
# Out:
# (1869, 16)
# (1869, 16)

# %%
new_data_down= pd.concat([category_no_down, category_yes], axis=0)
new_data_down
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6921    Male              0      No         No      54          Yes
# 6536    Male              0      No         No       1           No
# 2773    Male              0     Yes         No      24           No
# 2429    Male              1     Yes         No      59          Yes
# 3710    Male              0     Yes        Yes      10          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7021    Male              0      No         No      12          Yes
# 7026  Female              0      No         No       9          Yes
# 7032    Male              1      No         No       1          Yes
# 7034  Female              0      No         No      67          Yes
# 7041    Male              1     Yes         No       4          Yes
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 6921                   No                  Yes                   No
# 6536                   No                   No                   No
# 2773                   No                   No                  Yes
# 2429                  Yes                  Yes                  Yes
# 3710  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7021                   No                   No                   No
# 7026                   No                   No                   No
# 7032                   No                   No                   No
# 7034                  Yes                  Yes                  Yes
# 7041                   No                   No                   No
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 6921                   No                   No                   No
# 6536                   No                   No                   No
# 2773                   No                   No                   No
# 2429                   No                   No                   No
# 3710  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7021                  Yes                  Yes                   No
# 7026                   No                   No                   No
# 7032                   No                   No                   No
# 7034                   No                  Yes                   No
# 7041                   No                   No                   No
#
#             Contract  MonthlyCharges  TotalCharges Churn
# 6921  Month-to-month           79.85       4308.25    No
# 6536  Month-to-month           24.40         24.40    No
# 2773  Month-to-month           29.10        688.00    No
# 2429        One year           82.95       4903.15    No
# 3710        One year           20.45        242.40    No
# ...              ...             ...           ...   ...
# 7021        One year           59.80        727.80   Yes
# 7026  Month-to-month           44.20        403.35   Yes
# 7032  Month-to-month           75.75         75.75   Yes
# 7034  Month-to-month          102.95       6886.25   Yes
# 7041  Month-to-month           74.40        306.60   Yes
#
# [3738 rows x 16 columns]

# %%
#shuffling the data
new_data_down = new_data_down.sample(frac=1)
new_data_down['Churn'].value_counts()
# Out:
# Yes    1869
# No     1869
# Name: Churn, dtype: int64

# %% [markdown]
# *Upsampling*

# %%
category_yes_up = category_yes.sample(len(category_no), replace=True) 
print(category_yes_up.shape)
# Out:
# (5174, 16)

# %%
category_no.shape
# Out:
# (5174, 16)

# %%
new_data_up= pd.concat([category_no, category_yes_up], axis=0)
new_data_up
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 1396  Female              0      No         No      64          Yes
# 5588    Male              0      No         No       1          Yes
# 2638    Male              0      No         No      52          Yes
# 397   Female              0      No         No      34          Yes
# 2275    Male              0     Yes        Yes       1          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 3               Yes           No              Yes         Yes          No
# 6                No          Yes               No          No         Yes
# 7               Yes           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 1396             No           No              Yes          No         Yes
# 5588             No           No              Yes          No          No
# 2638             No          Yes              Yes         Yes         Yes
# 397              No          Yes               No          No          No
# 2275             No           No               No          No          No
#
#      StreamingMovies        Contract  MonthlyCharges  TotalCharges Churn
# 0                 No  Month-to-month           29.85         29.85    No
# 1                 No        One year           56.95       1889.50    No
# 3                 No        One year           42.30       1840.75    No
# 6                 No  Month-to-month           89.10       1949.40    No
# 7                 No  Month-to-month           29.75        301.90    No
# ...              ...             ...             ...           ...   ...
# 1396             Yes        One year          100.05       6254.20   Yes
# 5588              No  Month-to-month           49.65         49.65   Yes
# 2638             Yes        One year          105.00       5426.85   Yes
# 397               No  Month-to-month           73.95       2524.45   Yes
# 2275              No  Month-to-month           74.50         74.50   Yes
#
# [10348 rows x 16 columns]

# %%
new_data_up['Churn'].value_counts()
# Out:
# No     5174
# Yes    5174
# Name: Churn, dtype: int64

# %% [markdown]
# ##  Fit a Random forest Classifier on the data and compare the accuracy.

# %%
from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(random_state=0, max_features='sqrt', 
                             min_samples_leaf=1, min_samples_split=2, n_estimators=100)
cross_val_scores = cross_val_score(clf, X_train, y_train, cv=10)
print(np.mean(cross_val_scores))
# Out:
# 0.868082645497082
